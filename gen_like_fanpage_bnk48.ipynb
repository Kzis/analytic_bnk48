# %%
import requests
from bs4 import BeautifulSoup

def main():
    list_url_gen1 = get_url_gen1()
    list_url_gen2 = get_url_gen2()
    
    list_gen1 = get_like_facebook_fanpage_bnk48(list_url_gen1)
    list_gen2 = get_like_facebook_fanpage_bnk48(list_url_gen2)
    
    print(list_gen1)
    print(list_gen2)
        
def get_like_facebook_fanpage_bnk48(list_url):
    list_gen = []
    for url in list_url:
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')
        div_like = str(soup.find_all('div', class_='_4bl9')[1])
        like = div_like.split("<div>")[1][:7].split(",")[0] + div_like.split("<div>")[1][:7].split(",")[1]
        name = get_name_bnk48_by_url(url)
        bnk48 = {
            'name' : name,
            'like' : like,
            'url' : url
        }
        list_gen.append(bnk48)
        print("process --> name : {} , like : {} , url : {}".format(name, like , url))
    print("get like finish.")
    return list_gen

def get_name_bnk48_by_url(url):
    name = url.split("/")[3].split(".")
    return name[1] if 'bnk48' in name[0] else name[0]
        
def get_url_gen1():
    url_cherprang = "https://www.facebook.com/bnk48official.cherprang/" #1
    url_pun = "https://www.facebook.com/bnk48official.pun/" #2
    url_orn = "https://www.facebook.com/bnk48official.orn/" #3
    url_jennis = "https://www.facebook.com/bnk48official.jennis/" #4
    url_noey = "https://www.facebook.com/bnk48official.noey/" #5
    url_mobile = "https://www.facebook.com/bnk48official.mobile/" #6
    url_music = "https://www.facebook.com/bnk48official.music/" #7
    url_kaimook = "https://www.facebook.com/bnk48official.kaimook/" #8
    url_kaew = "https://www.facebook.com/bnk48official.kaew/" #9
    url_namneung = "https://www.facebook.com/bnk48official.namneung/" #10
    url_tarwaan = "https://www.facebook.com/bnk48official.tarwaan/" #11
    url_pupe = "https://www.facebook.com/bnk48official.pupe/" #12
    url_satchan = "https://www.facebook.com/bnk48official.satchan/" #13
    url_namsai = "https://www.facebook.com/bnk48official.namsai/" #14
    url_jane = "https://www.facebook.com/bnk48official.jane/" #15
    url_mind = "https://www.facebook.com/bnk48official.mind/" #16
    url_miori = "https://www.facebook.com/bnk48official.miori/" #17
    url_korn = "https://www.facebook.com/bnk48official.korn/" #18
    url_maysa = "https://www.facebook.com/bnk48official.maysa/" #19
    url_nink = "https://www.facebook.com/bnk48official.nink/" #20
    url_jaa = "https://www.facebook.com/bnk48official.jaa/" #21
    url_piam = "https://www.facebook.com/bnk48official.piam/" #22
    url_jib = "https://www.facebook.com/bnk48official.jib/" #23
    url_rina = "https://www.facebook.com/bnk48official.izutarina/" #24
    url_kate = "https://www.facebook.com/bnk48official.kate/" #25

    list_url_gen1 = [url_cherprang,url_pun, url_orn,url_jennis, url_noey,
                         url_mobile,url_music,url_kaimook,url_kaew,url_namneung,
                         url_tarwaan,url_pupe,url_satchan,url_namsai,url_jane,
                         url_mind,url_miori,url_korn,url_maysa,url_nink,url_jaa,
                         url_piam,url_jib,url_rina,url_kate]
    
    return list_url_gen1

def get_url_gen2():
    url_aom = "https://www.facebook.com/bnk48official.aom/" #1
    url_bamboo = "https://www.facebook.com/bnk48official.bamboo/" #2
    url_cake = "https://www.facebook.com/bnk48official.cake/" #3
    url_deenee = "https://www.facebook.com/bnk48official.deenee/" #4
    url_faii = "https://www.facebook.com/bnk48official.faii/" #5
    url_fifa = "https://www.facebook.com/bnk48official.fifa/" #6
    url_fond = "https://www.facebook.com/bnk48official.fond/" #7
    url_gygee = "https://www.facebook.com/bnk48official.gygee/" #8
    url_june = "https://www.facebook.com/bnk48official.june/" #9
    url_khamin = "https://www.facebook.com/bnk48official.khamin/" #10
    url_kheng = "https://www.facebook.com/bnk48official.kheng/" #11
    url_maira = "https://www.facebook.com/bnk48official.maira/" #12
    url_mewnich = "https://www.facebook.com/bnk48official.mewnich/" #13
    url_minmin = "https://www.facebook.com/bnk48official.minmin/" #14
    url_myyu = "https://www.facebook.com/bnk48official.myyu/" #15
    url_natherine = "https://www.facebook.com/bnk48official.natherine/" #16
    url_new = "https://www.facebook.com/bnk48official.new/" #17
    url_niky = "https://www.facebook.com/bnk48official.niky/" #18
    url_nine = "https://www.facebook.com/bnk48official.nine/" #19
    url_oom = "https://www.facebook.com/bnk48official.oom/" #20
    url_pakwan = "https://www.facebook.com/pakwan.bnk48official/" #21
    url_panda = "https://www.facebook.com/bnk48official.panda/" #22
    url_phukkhom = "https://www.facebook.com/bnk48official.phukkhom/" #23
    url_ratah = "https://www.facebook.com/bnk48official.ratah/" #24
    url_stang = "https://www.facebook.com/bnk48official.stang/" #25
    url_view = "https://www.facebook.com/bnk48official.view/" #26
    url_wee = "https://www.facebook.com/bnk48official.wee/" #27

    list_url_gen2 = [url_aom,url_bamboo,url_cake,url_deenee,url_faii,
                            url_fifa,url_fond,url_gygee,url_june,url_khamin,
                            url_kheng,url_maira,url_mewnich,url_minmin,url_myyu,
                            url_natherine,url_new,url_niky,url_nine,url_oom,
                            url_pakwan,url_panda,url_phukkhom,url_ratah,url_stang,
                            url_view,url_wee]
    
    return list_url_gen2

if __name__ == "__main__":
    main()
# Out:
# process --> name : cherprang , like : 564880 , url : https://www.facebook.com/bnk48official.cherprang/
# process --> name : pun , like : 557765 , url : https://www.facebook.com/bnk48official.pun/
# process --> name : orn , like : 358070 , url : https://www.facebook.com/bnk48official.orn/
# process --> name : jennis , like : 282632 , url : https://www.facebook.com/bnk48official.jennis/
# process --> name : noey , like : 281194 , url : https://www.facebook.com/bnk48official.noey/
# process --> name : mobile , like : 277943 , url : https://www.facebook.com/bnk48official.mobile/
# process --> name : music , like : 273365 , url : https://www.facebook.com/bnk48official.music/
# process --> name : kaimook , like : 253902 , url : https://www.facebook.com/bnk48official.kaimook/
# process --> name : kaew , like : 223731 , url : https://www.facebook.com/bnk48official.kaew/
# process --> name : namneung , like : 183736 , url : https://www.facebook.com/bnk48official.namneung/
# process --> name : tarwaan , like : 175011 , url : https://www.facebook.com/bnk48official.tarwaan/
# process --> name : pupe , like : 174859 , url : https://www.facebook.com/bnk48official.pupe/
# process --> name : satchan , like : 168806 , url : https://www.facebook.com/bnk48official.satchan/
# process --> name : namsai , like : 138960 , url : https://www.facebook.com/bnk48official.namsai/
# process --> name : jane , like : 131886 , url : https://www.facebook.com/bnk48official.jane/
# process --> name : mind , like : 111478 , url : https://www.facebook.com/bnk48official.mind/
# process --> name : miori , like : 108175 , url : https://www.facebook.com/bnk48official.miori/
# process --> name : korn , like : 108413 , url : https://www.facebook.com/bnk48official.korn/
# process --> name : maysa , like : 101359 , url : https://www.facebook.com/bnk48official.maysa/
# process --> name : nink , like : 87096  , url : https://www.facebook.com/bnk48official.nink/
# process --> name : jaa , like : 87091  , url : https://www.facebook.com/bnk48official.jaa/
# process --> name : piam , like : 83438  , url : https://www.facebook.com/bnk48official.piam/
# process --> name : jib , like : 82265  , url : https://www.facebook.com/bnk48official.jib/
# process --> name : izutarina , like : 77735  , url : https://www.facebook.com/bnk48official.izutarina/
# process --> name : kate , like : 58415  , url : https://www.facebook.com/bnk48official.kate/
# get like finish.
# process --> name : aom , like : 45780  , url : https://www.facebook.com/bnk48official.aom/
# process --> name : bamboo , like : 71015  , url : https://www.facebook.com/bnk48official.bamboo/
# process --> name : cake , like : 61152  , url : https://www.facebook.com/bnk48official.cake/
# process --> name : deenee , like : 33262  , url : https://www.facebook.com/bnk48official.deenee/
# process --> name : faii , like : 44134  , url : https://www.facebook.com/bnk48official.faii/
# process --> name : fifa , like : 29117  , url : https://www.facebook.com/bnk48official.fifa/
# process --> name : fond , like : 118480 , url : https://www.facebook.com/bnk48official.fond/
# process --> name : gygee , like : 54511  , url : https://www.facebook.com/bnk48official.gygee/
# process --> name : june , like : 119836 , url : https://www.facebook.com/bnk48official.june/
# process --> name : khamin , like : 32119  , url : https://www.facebook.com/bnk48official.khamin/
# process --> name : kheng , like : 48678  , url : https://www.facebook.com/bnk48official.kheng/
# process --> name : maira , like : 46325  , url : https://www.facebook.com/bnk48official.maira/
# process --> name : mewnich , like : 184582 , url : https://www.facebook.com/bnk48official.mewnich/
# process --> name : minmin , like : 64215  , url : https://www.facebook.com/bnk48official.minmin/
# process --> name : myyu , like : 48538  , url : https://www.facebook.com/bnk48official.myyu/
# process --> name : natherine , like : 170967 , url : https://www.facebook.com/bnk48official.natherine/
# process --> name : new , like : 75103  , url : https://www.facebook.com/bnk48official.new/
# process --> name : niky , like : 46210  , url : https://www.facebook.com/bnk48official.niky/
# process --> name : nine , like : 31997  , url : https://www.facebook.com/bnk48official.nine/
# process --> name : oom , like : 46040  , url : https://www.facebook.com/bnk48official.oom/
# process --> name : pakwan , like : 50450  , url : https://www.facebook.com/pakwan.bnk48official/
# process --> name : panda , like : 53487  , url : https://www.facebook.com/bnk48official.panda/
# process --> name : phukkhom , like : 91850  , url : https://www.facebook.com/bnk48official.phukkhom/
# process --> name : ratah , like : 116747 , url : https://www.facebook.com/bnk48official.ratah/
# process --> name : stang , like : 45404  , url : https://www.facebook.com/bnk48official.stang/
# process --> name : view , like : 56962  , url : https://www.facebook.com/bnk48official.view/
# process --> name : wee , like : 96610  , url : https://www.facebook.com/bnk48official.wee/
# get like finish.
# [{'name': 'cherprang', 'like': '564880', 'url': 'https://www.facebook.com/bnk48official.cherprang/'}, {'name': 'pun', 'like': '557765', 'url': 'https://www.facebook.com/bnk48official.pun/'}, {'name': 'orn', 'like': '358070', 'url': 'https://www.facebook.com/bnk48official.orn/'}, {'name': 'jennis', 'like': '282632', 'url': 'https://www.facebook.com/bnk48official.jennis/'}, {'name': 'noey', 'like': '281194', 'url': 'https://www.facebook.com/bnk48official.noey/'}, {'name': 'mobile', 'like': '277943', 'url': 'https://www.facebook.com/bnk48official.mobile/'}, {'name': 'music', 'like': '273365', 'url': 'https://www.facebook.com/bnk48official.music/'}, {'name': 'kaimook', 'like': '253902', 'url': 'https://www.facebook.com/bnk48official.kaimook/'}, {'name': 'kaew', 'like': '223731', 'url': 'https://www.facebook.com/bnk48official.kaew/'}, {'name': 'namneung', 'like': '183736', 'url': 'https://www.facebook.com/bnk48official.namneung/'}, {'name': 'tarwaan', 'like': '175011', 'url': 'https://www.facebook.com/bnk48official.tarwaan/'}, {'name': 'pupe', 'like': '174859', 'url': 'https://www.facebook.com/bnk48official.pupe/'}, {'name': 'satchan', 'like': '168806', 'url': 'https://www.facebook.com/bnk48official.satchan/'}, {'name': 'namsai', 'like': '138960', 'url': 'https://www.facebook.com/bnk48official.namsai/'}, {'name': 'jane', 'like': '131886', 'url': 'https://www.facebook.com/bnk48official.jane/'}, {'name': 'mind', 'like': '111478', 'url': 'https://www.facebook.com/bnk48official.mind/'}, {'name': 'miori', 'like': '108175', 'url': 'https://www.facebook.com/bnk48official.miori/'}, {'name': 'korn', 'like': '108413', 'url': 'https://www.facebook.com/bnk48official.korn/'}, {'name': 'maysa', 'like': '101359', 'url': 'https://www.facebook.com/bnk48official.maysa/'}, {'name': 'nink', 'like': '87096 ', 'url': 'https://www.facebook.com/bnk48official.nink/'}, {'name': 'jaa', 'like': '87091 ', 'url': 'https://www.facebook.com/bnk48official.jaa/'}, {'name': 'piam', 'like': '83438 ', 'url': 'https://www.facebook.com/bnk48official.piam/'}, {'name': 'jib', 'like': '82265 ', 'url': 'https://www.facebook.com/bnk48official.jib/'}, {'name': 'izutarina', 'like': '77735 ', 'url': 'https://www.facebook.com/bnk48official.izutarina/'}, {'name': 'kate', 'like': '58415 ', 'url': 'https://www.facebook.com/bnk48official.kate/'}]
# [{'name': 'aom', 'like': '45780 ', 'url': 'https://www.facebook.com/bnk48official.aom/'}, {'name': 'bamboo', 'like': '71015 ', 'url': 'https://www.facebook.com/bnk48official.bamboo/'}, {'name': 'cake', 'like': '61152 ', 'url': 'https://www.facebook.com/bnk48official.cake/'}, {'name': 'deenee', 'like': '33262 ', 'url': 'https://www.facebook.com/bnk48official.deenee/'}, {'name': 'faii', 'like': '44134 ', 'url': 'https://www.facebook.com/bnk48official.faii/'}, {'name': 'fifa', 'like': '29117 ', 'url': 'https://www.facebook.com/bnk48official.fifa/'}, {'name': 'fond', 'like': '118480', 'url': 'https://www.facebook.com/bnk48official.fond/'}, {'name': 'gygee', 'like': '54511 ', 'url': 'https://www.facebook.com/bnk48official.gygee/'}, {'name': 'june', 'like': '119836', 'url': 'https://www.facebook.com/bnk48official.june/'}, {'name': 'khamin', 'like': '32119 ', 'url': 'https://www.facebook.com/bnk48official.khamin/'}, {'name': 'kheng', 'like': '48678 ', 'url': 'https://www.facebook.com/bnk48official.kheng/'}, {'name': 'maira', 'like': '46325 ', 'url': 'https://www.facebook.com/bnk48official.maira/'}, {'name': 'mewnich', 'like': '184582', 'url': 'https://www.facebook.com/bnk48official.mewnich/'}, {'name': 'minmin', 'like': '64215 ', 'url': 'https://www.facebook.com/bnk48official.minmin/'}, {'name': 'myyu', 'like': '48538 ', 'url': 'https://www.facebook.com/bnk48official.myyu/'}, {'name': 'natherine', 'like': '170967', 'url': 'https://www.facebook.com/bnk48official.natherine/'}, {'name': 'new', 'like': '75103 ', 'url': 'https://www.facebook.com/bnk48official.new/'}, {'name': 'niky', 'like': '46210 ', 'url': 'https://www.facebook.com/bnk48official.niky/'}, {'name': 'nine', 'like': '31997 ', 'url': 'https://www.facebook.com/bnk48official.nine/'}, {'name': 'oom', 'like': '46040 ', 'url': 'https://www.facebook.com/bnk48official.oom/'}, {'name': 'pakwan', 'like': '50450 ', 'url': 'https://www.facebook.com/pakwan.bnk48official/'}, {'name': 'panda', 'like': '53487 ', 'url': 'https://www.facebook.com/bnk48official.panda/'}, {'name': 'phukkhom', 'like': '91850 ', 'url': 'https://www.facebook.com/bnk48official.phukkhom/'}, {'name': 'ratah', 'like': '116747', 'url': 'https://www.facebook.com/bnk48official.ratah/'}, {'name': 'stang', 'like': '45404 ', 'url': 'https://www.facebook.com/bnk48official.stang/'}, {'name': 'view', 'like': '56962 ', 'url': 'https://www.facebook.com/bnk48official.view/'}, {'name': 'wee', 'like': '96610 ', 'url': 'https://www.facebook.com/bnk48official.wee/'}]
